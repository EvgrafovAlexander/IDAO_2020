# %% [markdown]
# # 06_IDAO_Fit_models
#
# * обучение и сохранение моделей для каждого параметра отдельно

# %%
import sys
import warnings
warnings.filterwarnings('ignore')
import time

from sklearn.externals import joblib

import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import os.path

from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.preprocessing import MinMaxScaler

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import lightgbm as ltb
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# Выбираем параметр:

# %%
param = 'x'

# %% [markdown]
# Выбираем значимые признаки, полученные на этапе feature engeneering:

# %%
features_for_param = ['x_sim', 'y_sim', 'z_sim', 'Vx_sim', 'Vy_sim', 'Vz_sim',
            'sum_x_y', 'sum_x_z', 'sum_y_z',
            'dif_x_y', 'dif_x_z', 'dif_y_z',
            'mul_x_y', 'mul_x_z',
            'sum_Vx_Vy', 'sum_Vx_Vz', 'sum_Vy_Vz',
            'dif_Vx_Vy',
            'mul_Vx_Vy',
            'div_x_y']

model_LTB = ltb.LGBMRegressor(silent=True, random_state=42,
                                         learning_rate=0.3,
                                         max_depth=13,
                                         n_estimators=3000)

# %%
def smape(satellite_predicted_values, satellite_true_values): 
    # the division, addition and subtraction are pointwise 
    return np.mean(np.abs((satellite_predicted_values - satellite_true_values) 
        / (np.abs(satellite_predicted_values) + np.abs(satellite_true_values))))

# %%
smape_score = make_scorer(smape)

# %%
#Тренировочные данные
df_train = pd.read_csv('data/Track 1/train_final.csv')
#Тестовые данные
df_test = pd.read_csv('data/Track 1/test_final.csv')

df_train = df_train.drop(['Unnamed: 0'], axis=1)
df_test = df_test.drop(['Unnamed: 0'], axis=1)

# %%
df_train = df_train.drop(['time', 'date'], axis=1)
neworder = ['id', 'sat_id', 'x','y','z','Vx','Vy','Vz', 'x_sim','y_sim','z_sim','Vx_sim','Vy_sim','Vz_sim']
df_train=df_train.reindex(columns=neworder)
df_train['sat_id'] = df_train['sat_id'].astype('int64')

# %%
df_train.head(3)
# Out:
#        id  sat_id             x            y            z        Vx        Vy  \
# 0  1819.0       1  10390.313089 -2796.458271  3179.562085  2.520477  6.149930
# 1     NaN       1  10428.328529 -2424.698448  2989.854516  2.348307  6.134658
# 2     NaN       1  10466.343970 -2052.938626  2800.146946  2.176136  6.119386
#
#          Vz         x_sim        y_sim        z_sim    Vx_sim    Vy_sim  \
# 0 -2.827599  10405.813755 -2771.180760  3166.926302  2.508879  6.152996
# 1 -2.847816  10443.297921 -2399.492986  2977.491684  2.337052  6.137385
# 2 -2.868033  10480.782087 -2027.805212  2788.057066  2.165225  6.121774
#
#      Vz_sim
# 0 -2.826227
# 1 -2.846235
# 2 -2.866242

# %%
# form sat list
df_test['sat_id'] = df_test['sat_id'].astype('int64')
sat_id_test = list(set(df_test['sat_id']))
del(df_test)

# %%
def create_model(df, list_sat_id, list_of_features, model_LTB):
    for sat_id in list_sat_id:
        
        # create path for future model
        model_path = 'models/minute_' + param + '/lgb_' + param + '_' + str(sat_id) + '.pkl'
        
        #if model hasn't created earlier
        if not os.path.exists(model_path):
            df_one_sat = df_train.query('sat_id == @sat_id')

            df_one_sat['sum_x_y'] = df_one_sat['x_sim'] + df_one_sat['y_sim']
            df_one_sat['sum_x_z'] = df_one_sat['x_sim'] + df_one_sat['z_sim']
            df_one_sat['sum_y_z'] = df_one_sat['y_sim'] + df_one_sat['z_sim']

            df_one_sat['dif_x_y'] = df_one_sat['x_sim'] - df_one_sat['y_sim']
            df_one_sat['dif_x_z'] = df_one_sat['x_sim'] - df_one_sat['z_sim']
            df_one_sat['dif_y_z'] = df_one_sat['y_sim'] - df_one_sat['z_sim']

            df_one_sat['mul_x_y'] = df_one_sat['x_sim'] * df_one_sat['y_sim']
            df_one_sat['mul_x_z'] = df_one_sat['x_sim'] * df_one_sat['z_sim']
            df_one_sat['mul_y_z'] = df_one_sat['y_sim'] * df_one_sat['z_sim']

            df_one_sat['div_x_y'] = df_one_sat['x_sim'] / df_one_sat['y_sim']
            df_one_sat['div_x_z'] = df_one_sat['x_sim'] / df_one_sat['z_sim']
            df_one_sat['div_y_z'] = df_one_sat['y_sim'] / df_one_sat['z_sim']

            df_one_sat['sum_Vx_Vy'] = df_one_sat['Vx_sim'] + df_one_sat['Vy_sim']
            df_one_sat['sum_Vx_Vz'] = df_one_sat['Vx_sim'] + df_one_sat['Vz_sim']
            df_one_sat['sum_Vy_Vz'] = df_one_sat['Vy_sim'] + df_one_sat['Vz_sim']

            df_one_sat['dif_Vx_Vy'] = df_one_sat['Vx_sim'] - df_one_sat['Vy_sim']
            df_one_sat['dif_Vx_Vz'] = df_one_sat['Vx_sim'] - df_one_sat['Vz_sim']
            df_one_sat['dif_Vy_Vz'] = df_one_sat['Vy_sim'] - df_one_sat['Vz_sim']

            df_one_sat['mul_Vx_Vy'] = df_one_sat['Vx_sim'] * df_one_sat['Vy_sim']
            df_one_sat['mul_Vx_Vz'] = df_one_sat['Vx_sim'] * df_one_sat['Vz_sim']
            df_one_sat['mul_Vy_Vz'] = df_one_sat['Vy_sim'] * df_one_sat['Vz_sim']

            features = list_of_features
            target = [param]

            features_train = df_one_sat[features]
            target_train = df_one_sat[target]
            
            model_LTB.fit(features_train, target_train)
            joblib.dump(model_LTB, model_path)
            print('model', sat_id, 'created')
        else:
            print('model', sat_id, 'already created')

# %%
create_model(df_train, sat_id_test, features_for_param, model_LTB)
# Out:
# model 1 created
# model 514 created
# model 2 created
# model 3 created
# model 4 created
# model 6 created
# model 515 created
# model 516 created
# model 9 created
# model 517 created
# model 519 created
# model 522 created
# model 523 created
# model 524 created
# model 16 created
# model 528 created
# model 20 created
# model 22 created
# model 24 created
# model 25 created
# model 26 created
# model 27 created
# model 28 created
# model 29 created
# model 536 created
# model 537 created
# model 32 created
# model 539 created
# model 34 created
# model 35 created
# model 36 created
# model 37 created
# model 38 created
# model 39 created
# model 40 created
# model 41 created
# model 42 created
# model 547 created
# model 44 created
# model 45 created
# model 549 created
# model 550 created
# model 558 created
# model 49 created
# model 51 created
# model 52 created
# model 53 created
# model 54 created
# model 563 created
# model 565 created
# model 57 created
# model 566 created
# model 59 created
# model 567 created
# model 569 created
# model 572 created
# model 63 created
# model 64 created
# model 575 created
# model 578 created
# model 579 created
# model 68 created
# model 580 created
# model 70 created
# model 583 created
# model 584 created
# model 75 created
# model 587 created
# model 588 created
# model 593 created
# model 82 created
# model 595 created
# model 84 created
# model 596 created
# model 86 created
# model 597 created
# model 89 created
# model 90 created
# model 91 created
# model 92 created
# model 93 created
# model 96 created
# model 98 created
# model 100 created
# model 101 created
# model 102 created
# model 105 created
# model 106 created
# model 109 created
# model 110 created
# model 112 created
# model 113 created
# model 114 created
# model 117 created
# model 118 created
# model 120 created
# model 121 created
# model 123 created
# model 124 created
# model 125 created
# model 126 created
# model 127 created
# model 128 created
# model 130 created
# model 132 created
# model 133 created
# model 135 created
# model 138 created
# model 142 created
# model 143 created
# model 144 created
# model 145 created
# model 149 created
# model 151 created
# model 152 created
# model 153 created
# model 155 created
# model 156 created
# model 158 created
# model 159 created
# model 160 created
# model 162 created
# model 164 created
# model 165 created
# model 166 created
# model 542 created
# model 169 created
# model 170 created
# model 172 created
# model 173 created
# model 543 created
# model 177 created
# model 178 created
# model 544 created
# model 183 created
# model 186 created
# model 187 created
# model 188 created
# model 191 created
# model 193 created
# model 194 created
# model 195 created
# model 197 created
# model 548 created
# model 203 created
# model 205 created
# model 206 created
# model 207 created
# model 208 created
# model 209 created
# model 210 created
# model 211 created
# model 213 created
# model 219 created
# model 220 created
# model 222 created
# model 223 created
# model 225 created
# model 227 created
# model 228 created
# model 229 created
# model 230 created
# model 233 created
# model 236 created
# model 239 created
# model 240 created
# model 241 created
# model 242 created
# model 243 created
# model 244 created
# model 245 created
# model 247 created
# model 248 created
# model 251 created
# model 252 created
# model 253 created
# model 254 created
# model 261 created
# model 263 created
# model 264 created
# model 265 created
# model 268 created
# model 270 created
# model 275 created
# model 277 created
# model 278 created
# model 281 created
# model 284 created
# model 288 created
# model 292 created
# model 293 created
# model 294 created
# model 298 created
# model 299 created
# model 301 created
# model 304 created
# model 306 created
# model 309 created
# model 310 created
# model 312 created
# model 314 created
# model 316 created
# model 319 created
# model 324 created
# model 326 created
# model 332 created
# model 333 created
# model 342 created
# model 343 created
# model 344 created
# model 347 created
# model 348 created
# model 349 created
# model 356 created
# model 357 created
# model 358 created
# model 359 created
# model 362 created
# model 363 created
# model 372 created
# model 373 created
# model 375 created
# model 377 created
# model 380 created
# model 382 created
# model 384 created
# model 385 created
# model 387 created
# model 389 created
# model 390 created
# model 391 created
# model 392 created
# model 393 created
# model 395 created
# model 396 created
# model 399 created
# model 400 created
# model 407 created
# model 409 created
# model 411 created
# model 412 created
# model 415 created
# model 416 created
# model 417 created
# model 418 created
# model 419 created
# model 422 created
# model 423 created
# model 424 created
# model 426 created
# model 428 created
# model 435 created
# model 436 created
# model 437 created
# model 438 created
# model 440 created
# model 443 created
# model 446 created
# model 448 created
# model 449 created
# model 450 created
# model 452 created
# model 454 created
# model 455 created
# model 456 created
# model 457 created
# model 460 created
# model 462 created
# model 464 created
# model 465 created
# model 466 created
# model 467 created
# model 468 created
# model 470 created
# model 471 created
# model 473 created
# model 474 created
# model 475 created
# model 476 created
# model 477 created
# model 479 created
# model 480 created
# model 481 created
# model 482 created
# model 483 created
# model 486 created
# model 488 created
# model 489 created
# model 491 created
# model 495 created
# model 498 created
# model 499 created
# model 502 created
# model 504 created
# model 505 created
# model 506 created
# model 508 created
# model 509 created
# model 510 created
# model 511 created
